# %%
---
title: Finance dashboard
description: Dashboard with financial data
show-code: False
params:
    ticker: 
        input: select
        value: TSLA
        label: Select ticker
        choices: [TSLA, COIN, MSFT, PLTR, SNOW, NFLX]
---

# %%
import yfinance as yf
import mplfinance as mpf

# %% [markdown]
# # Historic Stock Price 🥶

# %%
tick = "TSLA"

# %%
print(f"Selected ticker: {tick}")
# Out:
# Selected ticker: TSLA

# %%
history = yf.Ticker(tick).history(period="3mo")

# %%
print(f"3 Month low {round(history.Low.min())}")
print(f"3 Month low {round(history.High.min())}")
# Out:
# 3 Month low 621
# 3 Month low 654

# %%
history.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-08-17  910.190002  928.969971  900.099976  911.989990  22922000
# 2022-08-18  918.000000  919.500000  905.559998  908.609985  15833500
# 2022-08-19  897.000000  901.080017  877.500000  890.000000  20417900
# 2022-08-22  875.739990  877.200012  858.890015  869.739990  18614400
# 2022-08-23  874.359985  896.479919  863.770020  889.359985  21221222
#
#             Dividends  Stock Splits
# Date
# 2022-08-17          0             0
# 2022-08-18          0             0
# 2022-08-19          0             0
# 2022-08-22          0             0
# 2022-08-23          0             0

# %%
mpf.plot(history, type='candle', mav = (7), figratio = (18,10))
